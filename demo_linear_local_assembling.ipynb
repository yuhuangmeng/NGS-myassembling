# %% [markdown]
# # Local Support Assembly Demo
#
# This notebook demonstrates exact support-closure local assembly. Python handles partitioning, support-patch construction, DoF/index bookkeeping, visualization, and verification. C++ performs the low-level finite element assembly over a supplied support patch and returns the local core matrix/vector.

# %%
import numpy as np
from ngsolve import *
from ngsolve.webgui import Draw
from netgen.geom2d import unit_square

from partition.metis import metis_partition_from_fes
from utils.patches import build_support_patches, draw_patch, print_patch_summary

import myassembling
print(myassembling)
print(myassembling.__file__)
print(dir(myassembling))

SetNumThreads(1)

# %% [markdown]
# ## Mesh, Space, And Integrators
#
# `bfi` is a generic NGSolve `BilinearFormIntegrator` and `lfi` is a generic `LinearFormIntegrator`. The C++ local assembler does not know the PDE; it only calls `CalcElementMatrix` or `CalcElementVector` on the supplied integrator. `SymbolicBFI(grad(u) * grad(v))` defines the Poisson stiffness matrix, while `SymbolicLFI(1.0 * v)` defines the linear right-hand side.

# %%
mesh = Mesh(unit_square.GenerateMesh(maxh=0.12, quad_dominated=False))
fes = H1(mesh, order=1, dirichlet="left|right|bottom|top")
u, v = fes.TnT()
bfi = SymbolicBFI(grad(u) * grad(v))
lfi = SymbolicLFI(1.0 * v)

print("ne =", mesh.ne, "ndof =", fes.ndof)

# %% [markdown]
# ## METIS Element Partition
#
# The helper in `partition/metis.py` builds a shared-DoF element graph and calls METIS. `core_partition` is non-overlapping. `overlapping_partition` is an optional graph-expanded partition for experiments; this expansion is separate from exact support-closure construction.

# %%
core_partition, overlapping_partition, cutcount = metis_partition_from_fes(
    fes,
    nparts=3,
    overlap_width=1,
    free_dofs_only=False,
)

# Use the METIS core partition for the exact support-closure demo.
# For experiments, set partition = overlapping_partition.
partition = overlapping_partition

print("METIS cutcount =", cutcount)
print("core element counts =", [len(p) for p in core_partition])
print("overlapping element counts =", [len(p) for p in overlapping_partition])

# %% [markdown]
# ## Visualize The Partition
#
# Each plot shows one subdomain. Value `1.0` marks elements in `core_partition[i]`. Value `1.5` would mark elements present only in `overlapping_partition[i]`. With `overlap_width=0`, only the core elements are shown.

# %%
l2 = L2(mesh, order=0)

for i, elements in enumerate(overlapping_partition):
    omega_i = GridFunction(l2, name=f"Omega_{i}")
    omega_i.vec[:] = 0

    core_set = set(core_partition[i])
    overlap_set = set(elements)

    for elnr in overlap_set - core_set:
        omega_i.vec[l2.GetDofNrs(ElementId(VOL, elnr))[0]] = 1.5
    for elnr in core_set:
        omega_i.vec[l2.GetDofNrs(ElementId(VOL, elnr))[0]] = 1.0

    Draw(omega_i, mesh, f"subdomain {i}: core=1, graph-expanded-only=1.5")

# %% [markdown]
# ## Build Support Patches In Python
#
# For each selected element set, Python constructs the exact support closure:
#
# - `core_dofs`: all global DoFs appearing on `core_elements`
# - `support_elements`: all elements whose DoF list intersects `core_dofs`
# - `support_dofs`: all global DoFs appearing on `support_elements`
# - `core_in_support`: local indices of `core_dofs` inside `support_dofs`

# %%
support_patches = build_support_patches(fes, partition)

for i, patch in enumerate(support_patches):
    print(f"Omega_{i}:")
    print_patch_summary(patch)
    for k, g in enumerate(patch.core_dofs):
        assert patch.support_dofs[patch.core_in_support[k]] == g

# %% [markdown]
# ## Assemble Local Matrices And Vectors In C++
#
# The C++ functions receive the support patch computed above. They loop over `support_elements`, compute element contributions with `bfi`/`lfi`, and return only the core-sized local matrix/vector using `core_dofs` as the local numbering. `support_dofs` and `core_in_support` are still passed in as metadata and consistency checks for the Python-built support closure.

# %%
local_mats = []
local_vecs = []
for patch in support_patches:
    local_A = myassembling.MyAssembleLocalMatrix(
        fes,
        bfi,
        patch.core_elements,
        patch.support_elements,
        patch.core_dofs,
        patch.support_dofs,
        patch.core_in_support,
    )
    local_b = myassembling.MyAssembleLocalVector(
        fes,
        lfi,
        patch.core_elements,
        patch.support_elements,
        patch.core_dofs,
        patch.support_dofs,
        patch.core_in_support,
    )
    local_mats.append(local_A)
    local_vecs.append(local_b)

for i, (local_A, local_b) in enumerate(zip(local_mats, local_vecs)):
    print(f"Omega_{i}: matrix shape =", (local_A.mat.height, local_A.mat.width),
          "vector length =", len(local_b.core_dofs))

# %% [markdown]
# ## Visualize Support Patches
#
# Each plot shows one support patch. Value `1` marks input core elements. Value `2` marks support-only elements that are outside the core but contribute to entries involving the core DoFs.

# %%
for i, patch in enumerate(support_patches):
    draw_patch(mesh, patch, name=f"Omega_{i}: core=1, support-only=2")

# %% [markdown]
# ## Verify Against Global Assembly
#
# The local matrix returned by C++ is already the core-core block:
#
# `A_local == A_global[core_dofs, core_dofs]`
#
# The local vector returned by C++ is already the core vector:
#
# `b_local == b_global[core_dofs]`
#
# We do not compare full support objects with global support subblocks. The support elements are only used as the integration domain needed to reproduce entries involving the core DoFs.

# %%
A_global = myassembling.MyAssembleMatrix(fes, bfi)
b_global = myassembling.MyAssembleVector(fes, lfi)

def dense_submatrix(A, rows, cols):
    return np.array([[A[i, j] for j in cols] for i in rows], dtype=float)

def vector_to_numpy(vec, n):
    return np.array([vec[i] for i in range(n)], dtype=float)

for i, (patch, local_A, local_b) in enumerate(zip(support_patches, local_mats, local_vecs)):
    A_core_local = np.array(local_A.mat.ToDense(), dtype=float)
    A_core_from_global = dense_submatrix(A_global, patch.core_dofs, patch.core_dofs)
    err_A = np.linalg.norm(A_core_local - A_core_from_global, ord=np.inf)

    b_core_local = vector_to_numpy(local_b.vec, len(patch.core_dofs))
    b_core_from_global = np.array([b_global[d] for d in patch.core_dofs], dtype=float)
    err_b = np.linalg.norm(b_core_local - b_core_from_global, ord=np.inf)

    print(f"Omega_{i}: ||A_local - A_global[core,core]||_inf = {err_A:.3e}")
    print(f"Omega_{i}: ||b_local - b_global[core]||_inf = {err_b:.3e}")
    assert err_A < 1e-12
    assert err_b < 1e-12
